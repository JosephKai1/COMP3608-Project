# %%
# %pip install git+https://github.com/WildlifeDatasets/wildlife-datasets@develop
# Out:
# Collecting git+https://github.com/WildlifeDatasets/wildlife-datasets@develop
#   Cloning https://github.com/WildlifeDatasets/wildlife-datasets (to revision develop) to /tmp/pip-req-build-wiu5yv16
#   Running command git clone --filter=blob:none --quiet https://github.com/WildlifeDatasets/wildlife-datasets /tmp/pip-req-build-wiu5yv16
#   Running command git checkout -b develop --track origin/develop
#   Switched to a new branch 'develop'
#   branch 'develop' set up to track 'origin/develop'.
#   Resolved https://github.com/WildlifeDatasets/wildlife-datasets to commit 298b9a0b566a56ccc76727928a1bb8126833730a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy>=1.19.4 (from wildlife-datasets==1.0.5)
#   Using cached numpy-2.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pandas>=1.1.4 (from wildlife-datasets==1.0.5)
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting tqdm>=4.62.3 (from wildlife-datasets==1.0.5)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting opencv-python>=4.5.5.62 (from wildlife-datasets==1.0.5)
#   Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting Pillow>=7.1.2 (from wildlife-datasets==1.0.5)
#   Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting scikit-learn>=1.0.1 (from wildlife-datasets==1.0.5)
#   Using cached scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting matplotlib>=3.5.1 (from wildlife-datasets==1.0.5)
#   Using cached matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pycocotools>=2.0.1 (from wildlife-datasets==1.0.5)
#   Using cached pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting datasets (from wildlife-datasets==1.0.5)
#   Using cached datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting gdown (from wildlife-datasets==1.0.5)
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting kaggle (from wildlife-datasets==1.0.5)
#   Using cached kaggle-1.7.4.2-py3-none-any.whl.metadata (16 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.5.1->wildlife-datasets==1.0.5)
#   Using cached contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.5.1->wildlife-datasets==1.0.5)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.5.1->wildlife-datasets==1.0.5)
#   Using cached fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.5.1->wildlife-datasets==1.0.5)
#   Using cached kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.5) (24.2)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.5.1->wildlife-datasets==1.0.5)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib>=3.5.1->wildlife-datasets==1.0.5) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->wildlife-datasets==1.0.5)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->wildlife-datasets==1.0.5)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn>=1.0.1->wildlife-datasets==1.0.5)
#   Using cached scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.0.1->wildlife-datasets==1.0.5)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.0.1->wildlife-datasets==1.0.5)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from datasets->wildlife-datasets==1.0.5) (3.17.0)
# Collecting pyarrow>=15.0.0 (from datasets->wildlife-datasets==1.0.5)
#   Using cached pyarrow-19.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->wildlife-datasets==1.0.5)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.32.2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from datasets->wildlife-datasets==1.0.5) (2.32.3)
# Collecting xxhash (from datasets->wildlife-datasets==1.0.5)
#   Using cached xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->wildlife-datasets==1.0.5)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->wildlife-datasets==1.0.5)
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets->wildlife-datasets==1.0.5)
#   Using cached aiohttp-3.11.16-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting huggingface-hub>=0.24.0 (from datasets->wildlife-datasets==1.0.5)
#   Using cached huggingface_hub-0.30.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pyyaml>=5.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from datasets->wildlife-datasets==1.0.5) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from gdown->wildlife-datasets==1.0.5) (4.13.3)
# Requirement already satisfied: bleach in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets==1.0.5) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets==1.0.5) (2025.1.31)
# Requirement already satisfied: charset-normalizer in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets==1.0.5) (3.4.1)
# Requirement already satisfied: idna in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets==1.0.5) (3.10)
# Collecting protobuf (from kaggle->wildlife-datasets==1.0.5)
#   Using cached protobuf-6.30.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting python-slugify (from kaggle->wildlife-datasets==1.0.5)
#   Using cached python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: setuptools>=21.0.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets==1.0.5) (75.8.0)
# Requirement already satisfied: six>=1.10 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets==1.0.5) (1.17.0)
# Collecting text-unidecode (from kaggle->wildlife-datasets==1.0.5)
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: urllib3>=1.15.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets==1.0.5) (2.3.0)
# Requirement already satisfied: webencodings in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets==1.0.5) (0.5.1)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets->wildlife-datasets==1.0.5)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->wildlife-datasets==1.0.5)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from aiohttp->datasets->wildlife-datasets==1.0.5) (25.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->wildlife-datasets==1.0.5)
#   Using cached frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->wildlife-datasets==1.0.5)
#   Using cached multidict-6.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets->wildlife-datasets==1.0.5)
#   Using cached propcache-0.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets->wildlife-datasets==1.0.5)
#   Using cached yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets->wildlife-datasets==1.0.5) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from beautifulsoup4->gdown->wildlife-datasets==1.0.5) (2.6)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown->wildlife-datasets==1.0.5)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Using cached matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Using cached numpy-2.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
# Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Using cached scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached datasets-3.5.0-py3-none-any.whl (491 kB)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached kaggle-1.7.4.2-py3-none-any.whl (173 kB)
# Using cached contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Using cached aiohttp-3.11.16-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Using cached huggingface_hub-0.30.1-py3-none-any.whl (481 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached pyarrow-19.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (42.1 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached protobuf-6.30.2-cp39-abi3-manylinux2014_x86_64.whl (316 kB)
# Using cached python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Using cached xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
# Using cached multidict-6.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (249 kB)
# Using cached propcache-0.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (245 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
# Building wheels for collected packages: wildlife-datasets
#   Building wheel for wildlife-datasets (pyproject.toml) ... done
#   Created wheel for wildlife-datasets: filename=wildlife_datasets-1.0.5-py3-none-any.whl size=88495 sha256=c7d19189ff8512015d50c2607712f7ba9a2693be3b888bb908b5833e9f135962
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7gmbegj6/wheels/2d/84/b9/40d8ea38f41340a93cbe0d60f5b88eebfa995f5ea6f4a29c3f
# Successfully built wildlife-datasets
# Installing collected packages: text-unidecode, pytz, xxhash, tzdata, tqdm, threadpoolctl, python-slugify, PySocks, pyparsing, pyarrow, protobuf, propcache, Pillow, numpy, multidict, kiwisolver, joblib, fsspec, frozenlist, fonttools, dill, cycler, aiohappyeyeballs, yarl, scipy, pandas, opencv-python, multiprocess, kaggle, huggingface-hub, contourpy, aiosignal, scikit-learn, matplotlib, gdown, aiohttp, pycocotools, datasets, wildlife-datasets
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.9
#     Uninstalling dill-0.3.9:
#       Successfully uninstalled dill-0.3.9
# Successfully installed Pillow-11.1.0 PySocks-1.7.1 aiohappyeyeballs-2.6.1 aiohttp-3.11.16 aiosignal-1.3.2 contourpy-1.3.1 cycler-0.12.1 datasets-3.5.0 dill-0.3.8 fonttools-4.57.0 frozenlist-1.5.0 fsspec-2024.12.0 gdown-5.2.0 huggingface-hub-0.30.1 joblib-1.4.2 kaggle-1.7.4.2 kiwisolver-1.4.8 matplotlib-3.10.1 multidict-6.3.2 multiprocess-0.70.16 numpy-2.2.4 opencv-python-4.11.0.86 pandas-2.2.3 propcache-0.3.1 protobuf-6.30.2 pyarrow-19.0.1 pycocotools-2.0.8 pyparsing-3.2.3 python-slugify-8.0.4 pytz-2025.2 scikit-learn-1.6.1 scipy-1.15.2 text-unidecode-1.3 threadpoolctl-3.6.0 tqdm-4.67.1 tzdata-2025.2 wildlife-datasets-1.0.5 xxhash-3.5.0 yarl-1.18.3

# %%
# %pip install git+https://github.com/WildlifeDatasets/wildlife-tools
# Out:
# Collecting git+https://github.com/WildlifeDatasets/wildlife-tools
#   Cloning https://github.com/WildlifeDatasets/wildlife-tools to /tmp/pip-req-build-3f11h3q7
#   Running command git clone --filter=blob:none --quiet https://github.com/WildlifeDatasets/wildlife-tools /tmp/pip-req-build-3f11h3q7
#   Resolved https://github.com/WildlifeDatasets/wildlife-tools to commit 71aa4656d16afe4caae6d84af642bab81dc2d06d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c (from wildlife-tools==1.0.1)
#   Using cached gluefactory-0.0-py3-none-any.whl
# Collecting torch>=2.0.1 (from wildlife-tools==1.0.1)
#   Using cached torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting timm>=0.9.2 (from wildlife-tools==1.0.1)
#   Using cached timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: numpy>=1.19.4 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-tools==1.0.1) (2.2.4)
# Requirement already satisfied: pandas>=1.1.4 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-tools==1.0.1) (2.2.3)
# Requirement already satisfied: tqdm>=4.62.3 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-tools==1.0.1) (4.67.1)
# Requirement already satisfied: opencv-python>=4.5.5.62 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-tools==1.0.1) (4.11.0.86)
# Requirement already satisfied: Pillow>=7.1.2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-tools==1.0.1) (11.1.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-tools==1.0.1) (1.6.1)
# Requirement already satisfied: pycocotools in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-tools==1.0.1) (2.0.8)
# Collecting tensorboard (from wildlife-tools==1.0.1)
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pytorch_metric_learning (from wildlife-tools==1.0.1)
#   Using cached pytorch_metric_learning-2.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting transformers>=4.30.2 (from wildlife-tools==1.0.1)
#   Using cached transformers-4.50.3-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: wildlife-datasets>=0.3.4 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-tools==1.0.1) (1.0.5)
# Collecting kornia>=0.6.12 (from wildlife-tools==1.0.1)
#   Using cached kornia-0.8.0-py2.py3-none-any.whl.metadata (17 kB)
# Collecting kornia_rs>=0.1.0 (from kornia>=0.6.12->wildlife-tools==1.0.1)
#   Using cached kornia_rs-0.1.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: packaging in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kornia>=0.6.12->wildlife-tools==1.0.1) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas>=1.1.4->wildlife-tools==1.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas>=1.1.4->wildlife-tools==1.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas>=1.1.4->wildlife-tools==1.0.1) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from scikit-learn>=1.0.1->wildlife-tools==1.0.1) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from scikit-learn>=1.0.1->wildlife-tools==1.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from scikit-learn>=1.0.1->wildlife-tools==1.0.1) (3.6.0)
# Collecting torchvision (from timm>=0.9.2->wildlife-tools==1.0.1)
#   Using cached torchvision-0.21.0-cp312-cp312-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: pyyaml in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from timm>=0.9.2->wildlife-tools==1.0.1) (6.0.2)
# Requirement already satisfied: huggingface_hub in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from timm>=0.9.2->wildlife-tools==1.0.1) (0.30.1)
# Collecting safetensors (from timm>=0.9.2->wildlife-tools==1.0.1)
#   Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (4.12.2)
# Collecting networkx (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (3.1.5)
# Requirement already satisfied: fsspec in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (2024.12.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from torch>=2.0.1->wildlife-tools==1.0.1) (75.8.0)
# Collecting sympy==1.13.1 (from torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=2.0.1->wildlife-tools==1.0.1)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers>=4.30.2->wildlife-tools==1.0.1)
#   Using cached regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from transformers>=4.30.2->wildlife-tools==1.0.1) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers>=4.30.2->wildlife-tools==1.0.1)
#   Using cached tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib>=3.5.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.10.1)
# Requirement already satisfied: datasets in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.5.0)
# Requirement already satisfied: gdown in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (5.2.0)
# Requirement already satisfied: kaggle in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.7.4.2)
# Collecting lightglue@ git+https://github.com/cvg/LightGlue.git (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Cloning https://github.com/cvg/LightGlue.git to /tmp/pip-install-5lvtkc0v/lightglue_6c51d8e953754a55938fad28796cd6f6
#   Running command git clone --filter=blob:none --quiet https://github.com/cvg/LightGlue.git /tmp/pip-install-5lvtkc0v/lightglue_6c51d8e953754a55938fad28796cd6f6
#   Resolved https://github.com/cvg/LightGlue.git to commit edb2b838efb2ecfe3f88097c5fad9887d95aedad
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting h5py (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting omegaconf (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting albumentations (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached albumentations-2.0.5-py3-none-any.whl.metadata (41 kB)
# Collecting seaborn (from gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting absl-py>=0.4 (from tensorboard->wildlife-tools==1.0.1)
#   Using cached absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->wildlife-tools==1.0.1)
#   Using cached grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard->wildlife-tools==1.0.1)
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorboard->wildlife-tools==1.0.1) (6.30.2)
# Requirement already satisfied: six>1.9 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorboard->wildlife-tools==1.0.1) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->wildlife-tools==1.0.1)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->wildlife-tools==1.0.1)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib>=3.5.1->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->wildlife-tools==1.0.1) (3.0.2)
# Collecting pydantic>=2.9.2 (from albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached pydantic-2.11.2-py3-none-any.whl.metadata (64 kB)
# Collecting albucore==0.0.23 (from albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.23->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached stringzilla-3.12.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (80 kB)
# Collecting simsimd>=5.9.2 (from albucore==0.0.23->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached simsimd-6.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (66 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.3.8)
# Requirement already satisfied: xxhash in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.70.16)
# Requirement already satisfied: aiohttp in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (3.11.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests->transformers>=4.30.2->wildlife-tools==1.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests->transformers>=4.30.2->wildlife-tools==1.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests->transformers>=4.30.2->wildlife-tools==1.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests->transformers>=4.30.2->wildlife-tools==1.0.1) (2025.1.31)
# Requirement already satisfied: beautifulsoup4 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from gdown->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (4.13.3)
# Requirement already satisfied: bleach in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (6.2.0)
# Requirement already satisfied: python-slugify in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (8.0.4)
# Requirement already satisfied: text-unidecode in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.3)
# Requirement already satisfied: webencodings in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from kaggle->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.5.1)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from aiohttp->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from aiohttp->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from aiohttp->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from aiohttp->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from aiohttp->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from aiohttp->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from aiohttp->datasets->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.18.3)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9.2->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.1 (from pydantic>=2.9.2->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached pydantic_core-2.33.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.9.2->albumentations->gluefactory@ git+https://github.com/cvg/glue-factory.git@1f56839db2242929960d70f85bfac6c19ef2821c->wildlife-tools==1.0.1)
#   Using cached typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from beautifulsoup4->gdown->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests[socks]->gdown->wildlife-datasets>=0.3.4->wildlife-tools==1.0.1) (1.7.1)
# Using cached kornia-0.8.0-py2.py3-none-any.whl (1.1 MB)
# Using cached timm-1.0.15-py3-none-any.whl (2.4 MB)
# Using cached torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl (766.6 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Using cached nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
# Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
# Using cached transformers-4.50.3-py3-none-any.whl (10.2 MB)
# Using cached pytorch_metric_learning-2.8.1-py3-none-any.whl (125 kB)
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Using cached absl_py-2.2.2-py3-none-any.whl (135 kB)
# Using cached grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Using cached kornia_rs-0.1.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
# Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Using cached torchvision-0.21.0-cp312-cp312-manylinux1_x86_64.whl (7.2 MB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached albumentations-2.0.5-py3-none-any.whl (290 kB)
# Using cached albucore-0.0.23-py3-none-any.whl (14 kB)
# Using cached h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
# Using cached pydantic-2.11.2-py3-none-any.whl (443 kB)
# Using cached pydantic_core-2.33.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached simsimd-6.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (633 kB)
# Using cached stringzilla-3.12.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (308 kB)
# Using cached typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: wildlife-tools, lightglue
#   Building wheel for wildlife-tools (pyproject.toml) ... done
#   Created wheel for wildlife-tools: filename=wildlife_tools-1.0.1-py3-none-any.whl size=33837 sha256=d6a272b1a2b6c6913dd141dbdd57d2351621936bf71fa3cf642309469e80880e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7aezcrce/wheels/8d/c5/05/047fdd4a52c29b09d212c66479d46a674267215340382c8784
#   Building wheel for lightglue (pyproject.toml) ... done
#   Created wheel for lightglue: filename=lightglue-0.0-py3-none-any.whl size=39542 sha256=cfe4889a180f12df2f7e04da0ca808f1b6b88f945ec8cfdc2cda99dd189cc1c2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7aezcrce/wheels/dc/16/88/ad4ddb490c3a6ff37eeface44b776cb588b19e169210e0fbf1
# Successfully built wildlife-tools lightglue
# Installing collected packages: triton, stringzilla, simsimd, nvidia-cusparselt-cu12, mpmath, antlr4-python3-runtime, werkzeug, typing-inspection, tensorboard-data-server, sympy, safetensors, regex, pydantic-core, opencv-python-headless, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, markdown, kornia_rs, h5py, grpcio, annotated-types, absl-py, tensorboard, pydantic, nvidia-cusparse-cu12, nvidia-cudnn-cu12, albucore, tokenizers, seaborn, nvidia-cusolver-cu12, albumentations, transformers, torch, torchvision, pytorch_metric_learning, kornia, timm, lightglue, gluefactory, wildlife-tools
# Successfully installed absl-py-2.2.2 albucore-0.0.23 albumentations-2.0.5 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 gluefactory-0.0 grpcio-1.71.0 h5py-3.13.0 kornia-0.8.0 kornia_rs-0.1.8 lightglue-0.0 markdown-3.7 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 omegaconf-2.3.0 opencv-python-headless-4.11.0.86 pydantic-2.11.2 pydantic-core-2.33.1 pytorch_metric_learning-2.8.1 regex-2024.11.6 safetensors-0.5.3 seaborn-0.13.2 simsimd-6.2.1 stringzilla-3.12.3 sympy-1.13.1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 timm-1.0.15 tokenizers-0.21.1 torch-2.6.0 torchvision-0.21.0 transformers-4.50.3 triton-3.2.0 typing-inspection-0.4.0 werkzeug-3.1.3 wildlife-tools-1.0.1

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (2.2.2)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.0.1-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (2.19.0)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting numpy<2.2.0,>=1.26.0 (from tensorflow)
#   Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: h5py>=3.11.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorflow) (3.13.0)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (645.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 49.2 MB/s eta 0:00:0000:0100:01
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.2 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 199.6 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 189.3 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 182.8 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading termcolor-3.0.1-py3-none-any.whl (7.2 kB)
# Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (403 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, termcolor, protobuf, optree, opt-einsum, numpy, google-pasta, gast, astunparse, ml-dtypes, keras, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.30.2
#     Uninstalling protobuf-6.30.2:
#       Successfully uninstalled protobuf-6.30.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# Successfully installed astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 keras-3.9.2 libclang-18.1.1 ml-dtypes-0.5.1 namex-0.0.8 numpy-2.1.3 opt-einsum-3.4.0 optree-0.14.1 protobuf-5.29.4 tensorflow-2.19.0 termcolor-3.0.1 wrapt-1.17.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from wildlife_datasets import analysis, datasets, loader

# %%
datasets.MacaqueFaces.get_data('data/MacaqueFaces')
# Out:
# DATASET MacaqueFaces: DOWNLOADING STARTED.
# MacaqueFaces.zip: 12.0MB [00:00, 23.8MB/s]
# MacaqueFaces_ImageInfo.csv: 410kB [00:00, 944kB/s]
# DATASET MacaqueFaces: EXTRACTING STARTED.
# DATASET MacaqueFaces: FINISHED.

# %%
d = loader.load_dataset(datasets.MacaqueFaces, 'data', 'dataframes')

# %%
ds = loader.load_datasets(datasets.names_all, 'data', 'dataframes')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 ds = loader.load_datasets(datasets.names_all, 'data', 'dataframes')
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/wildlife_datasets/loader/loader.py:50, in load_datasets(class_datasets, root_dataset, root_dataframe, **kwargs)
#      33 def load_datasets(
#      34         class_datasets: List[type],
#      35         root_dataset: str,
#      36         root_dataframe: str,
#      37         **kwargs
#      38         ) -> List[WildlifeDataset]:
#      39     """Loads multiple datasets as described in `load_dataset`.
#      40
#      41     Args:
#    (...)
#      47         The list of loaded datasets.
#      48     """
# ---> 50     return [load_dataset(class_dataset, root_dataset, root_dataframe, **kwargs) for class_dataset in class_datasets]
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/wildlife_datasets/loader/loader.py:76, in load_dataset(class_dataset, root_dataset, root_dataframe, overwrite, **kwargs)
#      74 # Check if the dataset is downloaded.
#      75 if not os.path.exists(root_dataset):
# ---> 76     raise(Exception('Data not found. Download them first.'))
#      78 # Get paths of the dataset and the pickled dataframe
#      79 root = get_dataset_folder(root_dataset, class_dataset)
#
# Exception: Data not found. Download them first.
